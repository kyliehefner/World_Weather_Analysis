# %% [markdown]
# # Generate 2,000 random latitudes and longitudes

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %% [markdown]
# # Get the nearest city using citipy module

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 738

# %% [markdown]
# # API call with OpenWeatherMap

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_desc})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hilo
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | saint george
# Processing Record 4 of Set 1 | chuy
# Processing Record 5 of Set 1 | quatre cocos
# Processing Record 6 of Set 1 | tuktoyaktuk
# Processing Record 7 of Set 1 | nanchong
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | butaritari
# Processing Record 10 of Set 1 | gejiu
# Processing Record 11 of Set 1 | oxford
# Processing Record 12 of Set 1 | yerbogachen
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | cabo san lucas
# Processing Record 15 of Set 1 | katsuura
# Processing Record 16 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 1 | lasa
# Processing Record 18 of Set 1 | wewak
# Processing Record 19 of Set 1 | yellowknife
# Processing Record 20 of Set 1 | kaitangata
# Processing Record 21 of Set 1 | atuona
# Processing Record 22 of Set 1 | edd
# Processing Record 23 of Set 1 | japura
# Processing Record 24 of Set 1 | hermanus
# Processing Record 25 of Set 1 | avera
# Processing Record 26 of Set 1 | victoria
# Processing Record 27 of Set 1 | anadyr
# Processing Record 28 of Set 1 | mwinilunga
# Processing Record 29 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 1 | ponta delgada
# Processing Record 31 of Set 1 | turtas
# Processing Record 32 of Set 1 | kijang
# Processing Record 33 of Set 1 | njeru
# Processing Record 34 of Set 1 | vaini
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | sao jose da coroa grande
# Processing Record 37 of Set 1 | linkoping
# Processing Record 38 of Set 1 | seoul
# Processing Record 39 of Set 1 | samana
# Processing Record 40 of Set 1 | qaqortoq
# Processing Record 41 of Set 1 | chokurdakh
# Processing Record 42 of Set 1 | mar del plata
# Processing Record 43 of Set 1 | asau
# Processing Record 44 of Set 1 | mataura
# Processing Record 45 of Set 1 | kamaishi
# Processing Record 46 of Set 1 | bondo
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | albany
# Processing Record 49 of Set 1 | qaanaaq
# Processing Record 50 of Set 1 | tautira
# Processing Record 1 of Set 2 | shimoda
# Processing Record 2 of Set 2 | bluff
# Processing Record 3 of Set 2 | hithadhoo
# Processing Record 4 of Set 2 | bukama
# Processing Record 5 of Set 2 | meulaboh
# Processing Record 6 of Set 2 | khash
# Processing Record 7 of Set 2 | barrow
# Processing Record 8 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 2 | kodiak
# Processing Record 10 of Set 2 | hobart
# Processing Record 11 of Set 2 | isangel
# Processing Record 12 of Set 2 | tual
# Processing Record 13 of Set 2 | east london
# Processing Record 14 of Set 2 | zhangjiakou
# Processing Record 15 of Set 2 | daru
# Processing Record 16 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 2 | sept-iles
# Processing Record 18 of Set 2 | new norfolk
# Processing Record 19 of Set 2 | komsomolskiy
# Processing Record 20 of Set 2 | atar
# Processing Record 21 of Set 2 | itoman
# Processing Record 22 of Set 2 | jamestown
# Processing Record 23 of Set 2 | tiksi
# Processing Record 24 of Set 2 | mitsamiouli
# Processing Record 25 of Set 2 | yuksekova
# Processing Record 26 of Set 2 | abu dhabi
# Processing Record 27 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 2 | hamilton
# Processing Record 29 of Set 2 | sambava
# Processing Record 30 of Set 2 | ramona
# Processing Record 31 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 2 | baruun-urt
# Processing Record 33 of Set 2 | arlit
# Processing Record 34 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 2 | adrar
# Processing Record 36 of Set 2 | ulaanbaatar
# Processing Record 37 of Set 2 | flinders
# Processing Record 38 of Set 2 | gatton
# Processing Record 39 of Set 2 | ewo
# Processing Record 40 of Set 2 | sobolevo
# Processing Record 41 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 2 | cape town
# Processing Record 43 of Set 2 | toamasina
# Processing Record 44 of Set 2 | camana
# Processing Record 45 of Set 2 | richards bay
# Processing Record 46 of Set 2 | kulhudhuffushi
# Processing Record 47 of Set 2 | waipawa
# Processing Record 48 of Set 2 | los llanos de aridane
# Processing Record 49 of Set 2 | shkotovo-22
# City not found. Skipping...
# Processing Record 50 of Set 2 | wagar
# Processing Record 1 of Set 3 | paita
# Processing Record 2 of Set 3 | siyabuswa
# Processing Record 3 of Set 3 | bossangoa
# Processing Record 4 of Set 3 | avarua
# Processing Record 5 of Set 3 | puerto ayora
# Processing Record 6 of Set 3 | makung
# City not found. Skipping...
# Processing Record 7 of Set 3 | tezu
# Processing Record 8 of Set 3 | ciras
# City not found. Skipping...
# Processing Record 9 of Set 3 | klaksvik
# Processing Record 10 of Set 3 | fortuna
# Processing Record 11 of Set 3 | beringovskiy
# Processing Record 12 of Set 3 | champerico
# Processing Record 13 of Set 3 | port alfred
# Processing Record 14 of Set 3 | toyooka
# Processing Record 15 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 3 | rayagada
# Processing Record 18 of Set 3 | yaan
# Processing Record 19 of Set 3 | talnakh
# Processing Record 20 of Set 3 | castro
# Processing Record 21 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 3 | shahrud
# Processing Record 23 of Set 3 | aksu
# Processing Record 24 of Set 3 | bethel
# Processing Record 25 of Set 3 | udayagiri
# Processing Record 26 of Set 3 | hervey bay
# Processing Record 27 of Set 3 | jalu
# Processing Record 28 of Set 3 | mataro
# Processing Record 29 of Set 3 | sangar
# Processing Record 30 of Set 3 | sabha
# Processing Record 31 of Set 3 | gat
# Processing Record 32 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 3 | atherton
# Processing Record 34 of Set 3 | chumikan
# Processing Record 35 of Set 3 | yashalta
# Processing Record 36 of Set 3 | vegreville
# Processing Record 37 of Set 3 | kapaa
# Processing Record 38 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 3 | mahajanga
# Processing Record 40 of Set 3 | nanortalik
# Processing Record 41 of Set 3 | luderitz
# Processing Record 42 of Set 3 | burica
# City not found. Skipping...
# Processing Record 43 of Set 3 | severo-kurilsk
# Processing Record 44 of Set 3 | pontianak
# Processing Record 45 of Set 3 | mount isa
# Processing Record 46 of Set 3 | mount gambier
# Processing Record 47 of Set 3 | cidreira
# Processing Record 48 of Set 3 | bahia blanca
# Processing Record 49 of Set 3 | ribeira grande
# Processing Record 50 of Set 3 | zhigansk
# Processing Record 1 of Set 4 | hobyo
# Processing Record 2 of Set 4 | lipin bor
# Processing Record 3 of Set 4 | lorengau
# Processing Record 4 of Set 4 | waingapu
# Processing Record 5 of Set 4 | pauini
# Processing Record 6 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 4 | ponta do sol
# Processing Record 8 of Set 4 | jiddah
# City not found. Skipping...
# Processing Record 9 of Set 4 | college
# Processing Record 10 of Set 4 | carnarvon
# Processing Record 11 of Set 4 | tuatapere
# Processing Record 12 of Set 4 | clyde river
# Processing Record 13 of Set 4 | olafsvik
# Processing Record 14 of Set 4 | tasiilaq
# Processing Record 15 of Set 4 | jieshi
# Processing Record 16 of Set 4 | iqaluit
# Processing Record 17 of Set 4 | aykhal
# Processing Record 18 of Set 4 | yar-sale
# Processing Record 19 of Set 4 | wencheng
# Processing Record 20 of Set 4 | kalispell
# Processing Record 21 of Set 4 | walvis bay
# Processing Record 22 of Set 4 | xiongyue
# Processing Record 23 of Set 4 | sola
# Processing Record 24 of Set 4 | bambanglipuro
# Processing Record 25 of Set 4 | kihei
# Processing Record 26 of Set 4 | half moon bay
# Processing Record 27 of Set 4 | taburi
# City not found. Skipping...
# Processing Record 28 of Set 4 | kishi
# Processing Record 29 of Set 4 | comodoro rivadavia
# Processing Record 30 of Set 4 | grand gaube
# Processing Record 31 of Set 4 | vila velha
# Processing Record 32 of Set 4 | teahupoo
# Processing Record 33 of Set 4 | coihaique
# Processing Record 34 of Set 4 | antofagasta
# Processing Record 35 of Set 4 | carutapera
# Processing Record 36 of Set 4 | owando
# Processing Record 37 of Set 4 | moerai
# Processing Record 38 of Set 4 | pochutla
# Processing Record 39 of Set 4 | shache
# Processing Record 40 of Set 4 | ayan
# Processing Record 41 of Set 4 | georgetown
# Processing Record 42 of Set 4 | oussouye
# Processing Record 43 of Set 4 | sovetskiy
# Processing Record 44 of Set 4 | tadine
# Processing Record 45 of Set 4 | dingle
# Processing Record 46 of Set 4 | cockburn town
# Processing Record 47 of Set 4 | beloha
# Processing Record 48 of Set 4 | cherskiy
# Processing Record 49 of Set 4 | tawkar
# City not found. Skipping...
# Processing Record 50 of Set 4 | inhambane
# Processing Record 1 of Set 5 | dembi dolo
# Processing Record 2 of Set 5 | dikson
# Processing Record 3 of Set 5 | arraial do cabo
# Processing Record 4 of Set 5 | kushiro
# Processing Record 5 of Set 5 | asyut
# Processing Record 6 of Set 5 | myitkyina
# Processing Record 7 of Set 5 | narsaq
# Processing Record 8 of Set 5 | thinadhoo
# Processing Record 9 of Set 5 | kavieng
# Processing Record 10 of Set 5 | saint-philippe
# Processing Record 11 of Set 5 | kaeo
# Processing Record 12 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 5 | matara
# Processing Record 14 of Set 5 | batemans bay
# Processing Record 15 of Set 5 | constitucion
# Processing Record 16 of Set 5 | suluq
# Processing Record 17 of Set 5 | rio gallegos
# Processing Record 18 of Set 5 | tabou
# Processing Record 19 of Set 5 | praia da vitoria
# Processing Record 20 of Set 5 | pushkinskiye gory
# Processing Record 21 of Set 5 | hovd
# Processing Record 22 of Set 5 | upernavik
# Processing Record 23 of Set 5 | najran
# Processing Record 24 of Set 5 | safaga
# Processing Record 25 of Set 5 | itupiranga
# Processing Record 26 of Set 5 | nouadhibou
# Processing Record 27 of Set 5 | halifax
# Processing Record 28 of Set 5 | tromso
# Processing Record 29 of Set 5 | kahului
# Processing Record 30 of Set 5 | torbay
# Processing Record 31 of Set 5 | mahadday weyne
# City not found. Skipping...
# Processing Record 32 of Set 5 | bambous virieux
# Processing Record 33 of Set 5 | mahebourg
# Processing Record 34 of Set 5 | wulanhaote
# City not found. Skipping...
# Processing Record 35 of Set 5 | ilulissat
# Processing Record 36 of Set 5 | leningradskiy
# Processing Record 37 of Set 5 | dangriga
# Processing Record 38 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 5 | puerto escondido
# Processing Record 40 of Set 5 | vardo
# Processing Record 41 of Set 5 | souillac
# Processing Record 42 of Set 5 | ndele
# Processing Record 43 of Set 5 | vidim
# Processing Record 44 of Set 5 | mezen
# Processing Record 45 of Set 5 | hasaki
# Processing Record 46 of Set 5 | yelizovo
# Processing Record 47 of Set 5 | tanout
# Processing Record 48 of Set 5 | male
# Processing Record 49 of Set 5 | saint anthony
# Processing Record 50 of Set 5 | saskylakh
# Processing Record 1 of Set 6 | fairbanks
# Processing Record 2 of Set 6 | grants
# Processing Record 3 of Set 6 | gogrial
# Processing Record 4 of Set 6 | sukhumi
# Processing Record 5 of Set 6 | safwah
# City not found. Skipping...
# Processing Record 6 of Set 6 | kalmunai
# Processing Record 7 of Set 6 | dongsheng
# Processing Record 8 of Set 6 | ismailia
# Processing Record 9 of Set 6 | nuuk
# Processing Record 10 of Set 6 | meadow lake
# Processing Record 11 of Set 6 | port moresby
# Processing Record 12 of Set 6 | tottori
# Processing Record 13 of Set 6 | chislaz
# Processing Record 14 of Set 6 | clacton-on-sea
# Processing Record 15 of Set 6 | malakwal
# Processing Record 16 of Set 6 | chone
# Processing Record 17 of Set 6 | coquimbo
# Processing Record 18 of Set 6 | bathsheba
# Processing Record 19 of Set 6 | encruzilhada do sul
# Processing Record 20 of Set 6 | saint-joseph
# Processing Record 21 of Set 6 | provideniya
# Processing Record 22 of Set 6 | kidal
# Processing Record 23 of Set 6 | norman wells
# Processing Record 24 of Set 6 | gimli
# Processing Record 25 of Set 6 | nishihara
# Processing Record 26 of Set 6 | bardsir
# Processing Record 27 of Set 6 | aketi
# Processing Record 28 of Set 6 | faanui
# Processing Record 29 of Set 6 | yulara
# Processing Record 30 of Set 6 | te karaka
# Processing Record 31 of Set 6 | asbury park
# Processing Record 32 of Set 6 | manacapuru
# Processing Record 33 of Set 6 | coari
# Processing Record 34 of Set 6 | urengoy
# Processing Record 35 of Set 6 | umm lajj
# Processing Record 36 of Set 6 | patacamaya
# Processing Record 37 of Set 6 | malanje
# Processing Record 38 of Set 6 | ziyamet
# City not found. Skipping...
# Processing Record 39 of Set 6 | booue
# Processing Record 40 of Set 6 | cayenne
# Processing Record 41 of Set 6 | selma
# Processing Record 42 of Set 6 | makakilo city
# Processing Record 43 of Set 6 | axim
# Processing Record 44 of Set 6 | verkhnevilyuysk
# Processing Record 45 of Set 6 | lompoc
# Processing Record 46 of Set 6 | codrington
# Processing Record 47 of Set 6 | tierra blanca
# Processing Record 48 of Set 6 | joao pinheiro
# Processing Record 49 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 50 of Set 6 | lagos
# Processing Record 1 of Set 7 | puerto leguizamo
# Processing Record 2 of Set 7 | thompson
# Processing Record 3 of Set 7 | the valley
# Processing Record 4 of Set 7 | port lincoln
# Processing Record 5 of Set 7 | saldanha
# Processing Record 6 of Set 7 | huarmey
# Processing Record 7 of Set 7 | chilakalurupet
# Processing Record 8 of Set 7 | ahipara
# Processing Record 9 of Set 7 | ust-tsilma
# Processing Record 10 of Set 7 | la baule-escoublac
# Processing Record 11 of Set 7 | batagay-alyta
# Processing Record 12 of Set 7 | pevek
# Processing Record 13 of Set 7 | buala
# Processing Record 14 of Set 7 | ngunguru
# Processing Record 15 of Set 7 | san patricio
# Processing Record 16 of Set 7 | port elizabeth
# Processing Record 17 of Set 7 | pacific grove
# Processing Record 18 of Set 7 | sao joao da barra
# Processing Record 19 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 7 | aklavik
# Processing Record 21 of Set 7 | aljezur
# Processing Record 22 of Set 7 | shupiyan
# Processing Record 23 of Set 7 | paraiso
# Processing Record 24 of Set 7 | san quintin
# Processing Record 25 of Set 7 | alihe
# Processing Record 26 of Set 7 | mareeba
# Processing Record 27 of Set 7 | sabaudia
# Processing Record 28 of Set 7 | yamada
# Processing Record 29 of Set 7 | ryotsu
# Processing Record 30 of Set 7 | majene
# Processing Record 31 of Set 7 | ranong
# Processing Record 32 of Set 7 | palu
# Processing Record 33 of Set 7 | kununurra
# Processing Record 34 of Set 7 | svetlyy
# Processing Record 35 of Set 7 | balsas
# Processing Record 36 of Set 7 | pombia
# Processing Record 37 of Set 7 | lingao
# Processing Record 38 of Set 7 | arman
# Processing Record 39 of Set 7 | mamallapuram
# Processing Record 40 of Set 7 | golden
# Processing Record 41 of Set 7 | maraa
# Processing Record 42 of Set 7 | ganzhou
# Processing Record 43 of Set 7 | karlshamn
# Processing Record 44 of Set 7 | westport
# Processing Record 45 of Set 7 | bengkulu
# Processing Record 46 of Set 7 | ambilobe
# Processing Record 47 of Set 7 | touros
# Processing Record 48 of Set 7 | vavuniya
# Processing Record 49 of Set 7 | mecca
# Processing Record 50 of Set 7 | mujiayingzi
# Processing Record 1 of Set 8 | bayangol
# Processing Record 2 of Set 8 | kroya
# Processing Record 3 of Set 8 | ust-omchug
# Processing Record 4 of Set 8 | tessalit
# Processing Record 5 of Set 8 | esperance
# Processing Record 6 of Set 8 | volsk
# Processing Record 7 of Set 8 | ishigaki
# Processing Record 8 of Set 8 | san cristobal
# Processing Record 9 of Set 8 | nikolskoye
# Processing Record 10 of Set 8 | paamiut
# Processing Record 11 of Set 8 | sinnamary
# Processing Record 12 of Set 8 | juneau
# Processing Record 13 of Set 8 | khatanga
# Processing Record 14 of Set 8 | yangambi
# Processing Record 15 of Set 8 | kukes
# Processing Record 16 of Set 8 | chico
# Processing Record 17 of Set 8 | haines junction
# Processing Record 18 of Set 8 | canton
# Processing Record 19 of Set 8 | guilin
# Processing Record 20 of Set 8 | ribeira brava
# Processing Record 21 of Set 8 | te anau
# Processing Record 22 of Set 8 | muros
# Processing Record 23 of Set 8 | nemuro
# Processing Record 24 of Set 8 | tiznit
# Processing Record 25 of Set 8 | gouyave
# Processing Record 26 of Set 8 | centerville
# Processing Record 27 of Set 8 | tilichiki
# Processing Record 28 of Set 8 | shingu
# Processing Record 29 of Set 8 | pangnirtung
# Processing Record 30 of Set 8 | pleasanton
# Processing Record 31 of Set 8 | port hardy
# Processing Record 32 of Set 8 | lebu
# Processing Record 33 of Set 8 | warmbad
# Processing Record 34 of Set 8 | salinopolis
# Processing Record 35 of Set 8 | san jose
# Processing Record 36 of Set 8 | severo-yeniseyskiy
# Processing Record 37 of Set 8 | pereira barreto
# Processing Record 38 of Set 8 | rabo de peixe
# Processing Record 39 of Set 8 | mapastepec
# Processing Record 40 of Set 8 | el astillero
# Processing Record 41 of Set 8 | kinwat
# Processing Record 42 of Set 8 | johi
# Processing Record 43 of Set 8 | ojinaga
# Processing Record 44 of Set 8 | assiniboia
# Processing Record 45 of Set 8 | geraldton
# Processing Record 46 of Set 8 | nizhniy kuranakh
# Processing Record 47 of Set 8 | makinsk
# Processing Record 48 of Set 8 | bahawalpur
# Processing Record 49 of Set 8 | great falls
# Processing Record 50 of Set 8 | kruisfontein
# Processing Record 1 of Set 9 | domna
# Processing Record 2 of Set 9 | okha
# Processing Record 3 of Set 9 | lahan
# Processing Record 4 of Set 9 | rabaul
# Processing Record 5 of Set 9 | sorland
# Processing Record 6 of Set 9 | guerrero
# Processing Record 7 of Set 9 | timbiqui
# Processing Record 8 of Set 9 | bolshiye kaybitsy
# City not found. Skipping...
# Processing Record 9 of Set 9 | balabac
# Processing Record 10 of Set 9 | zhetybay
# City not found. Skipping...
# Processing Record 11 of Set 9 | puri
# Processing Record 12 of Set 9 | rundu
# Processing Record 13 of Set 9 | bantry
# Processing Record 14 of Set 9 | haapiti
# Processing Record 15 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 16 of Set 9 | youkounkoun
# Processing Record 17 of Set 9 | votkinsk
# Processing Record 18 of Set 9 | falmouth
# Processing Record 19 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 20 of Set 9 | riyadh
# Processing Record 21 of Set 9 | semirom
# Processing Record 22 of Set 9 | kalengwa
# Processing Record 23 of Set 9 | urcos
# Processing Record 24 of Set 9 | hofn
# Processing Record 25 of Set 9 | taltal
# Processing Record 26 of Set 9 | ilhabela
# Processing Record 27 of Set 9 | miyoshi
# Processing Record 28 of Set 9 | fandriana
# Processing Record 29 of Set 9 | maceio
# Processing Record 30 of Set 9 | airai
# Processing Record 31 of Set 9 | hokitika
# Processing Record 32 of Set 9 | soanierana ivongo
# Processing Record 33 of Set 9 | beisfjord
# Processing Record 34 of Set 9 | constantine
# Processing Record 35 of Set 9 | awjilah
# Processing Record 36 of Set 9 | tahta
# Processing Record 37 of Set 9 | sitka
# Processing Record 38 of Set 9 | margate
# Processing Record 39 of Set 9 | fukue
# Processing Record 40 of Set 9 | kuremaa
# Processing Record 41 of Set 9 | kisangani
# Processing Record 42 of Set 9 | jining
# Processing Record 43 of Set 9 | morgan city
# Processing Record 44 of Set 9 | jahangirpur
# Processing Record 45 of Set 9 | brae
# Processing Record 46 of Set 9 | salamiyah
# Processing Record 47 of Set 9 | usinsk
# Processing Record 48 of Set 9 | glasgow
# Processing Record 49 of Set 9 | longyearbyen
# Processing Record 50 of Set 9 | kasongo-lunda
# Processing Record 1 of Set 10 | maragogi
# Processing Record 2 of Set 10 | pisco
# Processing Record 3 of Set 10 | grindavik
# Processing Record 4 of Set 10 | sistranda
# Processing Record 5 of Set 10 | laguna
# Processing Record 6 of Set 10 | taylorville
# Processing Record 7 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 10 | playa vicente
# Processing Record 9 of Set 10 | tazovskiy
# Processing Record 10 of Set 10 | melhus
# Processing Record 11 of Set 10 | rocha
# Processing Record 12 of Set 10 | takoradi
# Processing Record 13 of Set 10 | srednekolymsk
# Processing Record 14 of Set 10 | nabire
# Processing Record 15 of Set 10 | koboldo
# City not found. Skipping...
# Processing Record 16 of Set 10 | derzhavinsk
# Processing Record 17 of Set 10 | zhitikara
# City not found. Skipping...
# Processing Record 18 of Set 10 | kajaani
# Processing Record 19 of Set 10 | dali
# Processing Record 20 of Set 10 | karratha
# Processing Record 21 of Set 10 | gainsborough
# Processing Record 22 of Set 10 | dengzhou
# Processing Record 23 of Set 10 | ust-nera
# Processing Record 24 of Set 10 | panaba
# Processing Record 25 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 26 of Set 10 | zyryanka
# Processing Record 27 of Set 10 | batagay
# Processing Record 28 of Set 10 | yertarskiy
# Processing Record 29 of Set 10 | ibra
# Processing Record 30 of Set 10 | smithers
# Processing Record 31 of Set 10 | awbari
# Processing Record 32 of Set 10 | qui nhon
# Processing Record 33 of Set 10 | tatawin
# Processing Record 34 of Set 10 | lagoa
# Processing Record 35 of Set 10 | manzil jamil
# City not found. Skipping...
# Processing Record 36 of Set 10 | harper
# Processing Record 37 of Set 10 | banjar
# Processing Record 38 of Set 10 | chinsali
# Processing Record 39 of Set 10 | silute
# Processing Record 40 of Set 10 | machado
# Processing Record 41 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 42 of Set 10 | muli
# Processing Record 43 of Set 10 | dawei
# Processing Record 44 of Set 10 | sur
# Processing Record 45 of Set 10 | waddan
# Processing Record 46 of Set 10 | bacuit
# City not found. Skipping...
# Processing Record 47 of Set 10 | emerald
# Processing Record 48 of Set 10 | sarlat-la-caneda
# Processing Record 49 of Set 10 | samarai
# Processing Record 50 of Set 10 | palkino
# Processing Record 1 of Set 11 | asfi
# Processing Record 2 of Set 11 | altoona
# Processing Record 3 of Set 11 | magadan
# Processing Record 4 of Set 11 | kharan
# Processing Record 5 of Set 11 | fuerte olimpo
# Processing Record 6 of Set 11 | tigil
# Processing Record 7 of Set 11 | ostrovnoy
# Processing Record 8 of Set 11 | manzanillo
# Processing Record 9 of Set 11 | karachi
# Processing Record 10 of Set 11 | dodola
# Processing Record 11 of Set 11 | koygorodok
# Processing Record 12 of Set 11 | lakselv
# Processing Record 13 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 14 of Set 11 | homer
# Processing Record 15 of Set 11 | roma
# Processing Record 16 of Set 11 | marrakesh
# Processing Record 17 of Set 11 | jijiga
# Processing Record 18 of Set 11 | vangaindrano
# Processing Record 19 of Set 11 | aswan
# Processing Record 20 of Set 11 | kushima
# Processing Record 21 of Set 11 | gigmoto
# Processing Record 22 of Set 11 | san angelo
# Processing Record 23 of Set 11 | houma
# Processing Record 24 of Set 11 | ancud
# Processing Record 25 of Set 11 | isilkul
# Processing Record 26 of Set 11 | las vegas
# Processing Record 27 of Set 11 | antalaha
# Processing Record 28 of Set 11 | rincon
# Processing Record 29 of Set 11 | valdagno
# Processing Record 30 of Set 11 | cockburn harbour
# City not found. Skipping...
# Processing Record 31 of Set 11 | cairns
# Processing Record 32 of Set 11 | litovko
# Processing Record 33 of Set 11 | vrangel
# Processing Record 34 of Set 11 | kiama
# Processing Record 35 of Set 11 | santa rosalia
# Processing Record 36 of Set 11 | coahuayana
# Processing Record 37 of Set 11 | belaya gora
# Processing Record 38 of Set 11 | pedernales
# Processing Record 39 of Set 11 | umm durman
# City not found. Skipping...
# Processing Record 40 of Set 11 | ajaccio
# Processing Record 41 of Set 11 | jacksonville
# Processing Record 42 of Set 11 | hualmay
# Processing Record 43 of Set 11 | manicore
# Processing Record 44 of Set 11 | khani
# Processing Record 45 of Set 11 | roebourne
# Processing Record 46 of Set 11 | uhlove
# Processing Record 47 of Set 11 | tingi
# Processing Record 48 of Set 11 | changji
# Processing Record 49 of Set 11 | rio grande
# Processing Record 50 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 1 of Set 12 | dunedin
# Processing Record 2 of Set 12 | mus
# Processing Record 3 of Set 12 | hambantota
# Processing Record 4 of Set 12 | musoma
# Processing Record 5 of Set 12 | oltu
# Processing Record 6 of Set 12 | trincomalee
# Processing Record 7 of Set 12 | taree
# Processing Record 8 of Set 12 | cercal
# Processing Record 9 of Set 12 | labuan
# Processing Record 10 of Set 12 | palana
# Processing Record 11 of Set 12 | rawson
# Processing Record 12 of Set 12 | tura
# Processing Record 13 of Set 12 | nezhinka
# Processing Record 14 of Set 12 | ahuimanu
# Processing Record 15 of Set 12 | manggar
# Processing Record 16 of Set 12 | mahon
# Processing Record 17 of Set 12 | buenos aires
# Processing Record 18 of Set 12 | general pico
# Processing Record 19 of Set 12 | maham
# Processing Record 20 of Set 12 | manado
# Processing Record 21 of Set 12 | akcaabat
# Processing Record 22 of Set 12 | abalak
# Processing Record 23 of Set 12 | kargil
# Processing Record 24 of Set 12 | moyale
# Processing Record 25 of Set 12 | maniitsoq
# Processing Record 26 of Set 12 | kawalu
# Processing Record 27 of Set 12 | powell
# Processing Record 28 of Set 12 | hunza
# City not found. Skipping...
# Processing Record 29 of Set 12 | kerman
# Processing Record 30 of Set 12 | port hedland
# Processing Record 31 of Set 12 | zeya
# Processing Record 32 of Set 12 | yeppoon
# Processing Record 33 of Set 12 | padang
# Processing Record 34 of Set 12 | onguday
# Processing Record 35 of Set 12 | damara
# Processing Record 36 of Set 12 | plymouth
# Processing Record 37 of Set 12 | kamenka
# Processing Record 38 of Set 12 | quesnel
# Processing Record 39 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 40 of Set 12 | kortkeros
# Processing Record 41 of Set 12 | mazagao
# Processing Record 42 of Set 12 | guerrero negro
# Processing Record 43 of Set 12 | sancti spiritus
# Processing Record 44 of Set 12 | kupang
# Processing Record 45 of Set 12 | bilibino
# Processing Record 46 of Set 12 | otradnoye
# Processing Record 47 of Set 12 | oktyabrskiy
# Processing Record 48 of Set 12 | kroonstad
# Processing Record 49 of Set 12 | berlevag
# Processing Record 50 of Set 12 | porto santo
# Processing Record 1 of Set 13 | nortelandia
# Processing Record 2 of Set 13 | winnemucca
# Processing Record 3 of Set 13 | ahumada
# City not found. Skipping...
# Processing Record 4 of Set 13 | mandalgovi
# Processing Record 5 of Set 13 | vallenar
# Processing Record 6 of Set 13 | novaya igirma
# Processing Record 7 of Set 13 | umm kaddadah
# Processing Record 8 of Set 13 | sydney
# Processing Record 9 of Set 13 | carahue
# Processing Record 10 of Set 13 | ulladulla
# Processing Record 11 of Set 13 | jipijapa
# Processing Record 12 of Set 13 | novo aripuana
# Processing Record 13 of Set 13 | salalah
# Processing Record 14 of Set 13 | tashtyp
# Processing Record 15 of Set 13 | redlands
# Processing Record 16 of Set 13 | troitskoye
# Processing Record 17 of Set 13 | broome
# Processing Record 18 of Set 13 | north myrtle beach
# Processing Record 19 of Set 13 | borogontsy
# Processing Record 20 of Set 13 | alugan
# Processing Record 21 of Set 13 | laramie
# Processing Record 22 of Set 13 | auki
# Processing Record 23 of Set 13 | akyab
# Processing Record 24 of Set 13 | pundaguitan
# Processing Record 25 of Set 13 | nicoya
# Processing Record 26 of Set 13 | fez
# Processing Record 27 of Set 13 | maningrida
# Processing Record 28 of Set 13 | pozo colorado
# Processing Record 29 of Set 13 | pangoa
# Processing Record 30 of Set 13 | burley
# Processing Record 31 of Set 13 | mackenzie
# Processing Record 32 of Set 13 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 33 of Set 13 | plouzane
# Processing Record 34 of Set 13 | betare oya
# Processing Record 35 of Set 13 | brewster
# Processing Record 36 of Set 13 | denpasar
# Processing Record 37 of Set 13 | palmer
# Processing Record 38 of Set 13 | balykshi
# Processing Record 39 of Set 13 | kodinar
# Processing Record 40 of Set 13 | vila franca do campo
# Processing Record 41 of Set 13 | along
# Processing Record 42 of Set 13 | melfi
# Processing Record 43 of Set 13 | marsabit
# Processing Record 44 of Set 13 | genhe
# Processing Record 45 of Set 13 | dunmore east
# Processing Record 46 of Set 13 | enzan
# Processing Record 47 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 48 of Set 13 | grand baie
# Processing Record 49 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 50 of Set 13 | caravelas
# Processing Record 1 of Set 14 | zhumadian
# Processing Record 2 of Set 14 | mashhad
# Processing Record 3 of Set 14 | saurimo
# Processing Record 4 of Set 14 | qeshm
# Processing Record 5 of Set 14 | amapa
# Processing Record 6 of Set 14 | honiara
# Processing Record 7 of Set 14 | marsh harbour
# Processing Record 8 of Set 14 | kijini
# Processing Record 9 of Set 14 | nakasongola
# Processing Record 10 of Set 14 | sao filipe
# Processing Record 11 of Set 14 | salym
# Processing Record 12 of Set 14 | acapulco
# Processing Record 13 of Set 14 | aukra
# Processing Record 14 of Set 14 | baglan
# Processing Record 15 of Set 14 | machinga
# Processing Record 16 of Set 14 | itarema
# Processing Record 17 of Set 14 | lang son
# Processing Record 18 of Set 14 | bacolod
# Processing Record 19 of Set 14 | kindu
# Processing Record 20 of Set 14 | el alto
# Processing Record 21 of Set 14 | maumere
# Processing Record 22 of Set 14 | hoogeveen
# Processing Record 23 of Set 14 | togitsu
# Processing Record 24 of Set 14 | serebryansk
# Processing Record 25 of Set 14 | viksoyri
# City not found. Skipping...
# Processing Record 26 of Set 14 | aurora
# Processing Record 27 of Set 14 | kropotkin
# Processing Record 28 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 29 of Set 14 | powell river
# Processing Record 30 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 31 of Set 14 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 32 of Set 14 | bartica
# Processing Record 33 of Set 14 | cusset
# Processing Record 34 of Set 14 | bodden town
# Processing Record 35 of Set 14 | ixtapa
# Processing Record 36 of Set 14 | atasu
# Processing Record 37 of Set 14 | scarborough
# Processing Record 38 of Set 14 | sao jose do belmonte
# Processing Record 39 of Set 14 | karomatan
# City not found. Skipping...
# Processing Record 40 of Set 14 | iquique
# Processing Record 41 of Set 14 | chokwe
# Processing Record 42 of Set 14 | aleksandrov gay
# Processing Record 43 of Set 14 | brightwater
# Processing Record 44 of Set 14 | noumea
# Processing Record 45 of Set 14 | adre
# Processing Record 46 of Set 14 | elesbao veloso
# Processing Record 47 of Set 14 | campbell river
# Processing Record 48 of Set 14 | vila
# Processing Record 49 of Set 14 | bonfim
# Processing Record 50 of Set 14 | chandrakona
# Processing Record 1 of Set 15 | korla
# Processing Record 2 of Set 15 | belyy yar
# Processing Record 3 of Set 15 | bilma
# Processing Record 4 of Set 15 | valparaiso
# Processing Record 5 of Set 15 | abu jubayhah
# City not found. Skipping...
# Processing Record 6 of Set 15 | latisana
# Processing Record 7 of Set 15 | biak
# Processing Record 8 of Set 15 | dinar
# Processing Record 9 of Set 15 | yerofey pavlovich
# Processing Record 10 of Set 15 | yurimaguas
# Processing Record 11 of Set 15 | alenquer
# Processing Record 12 of Set 15 | mayo
# Processing Record 13 of Set 15 | teguldet
# Processing Record 14 of Set 15 | whitehaven
# Processing Record 15 of Set 15 | mehamn
# Processing Record 16 of Set 15 | lhokseumawe
# Processing Record 17 of Set 15 | marawi
# Processing Record 18 of Set 15 | vestmannaeyjar
# Processing Record 19 of Set 15 | jiangkou
# Processing Record 20 of Set 15 | canutama
# Processing Record 21 of Set 15 | yashan
# Processing Record 22 of Set 15 | kontagora
# Processing Record 23 of Set 15 | mao
# Processing Record 24 of Set 15 | kaoma
# Processing Record 25 of Set 15 | zhanatas
# City not found. Skipping...
# Processing Record 26 of Set 15 | cedral
# Processing Record 27 of Set 15 | namatanai
# Processing Record 28 of Set 15 | aku
# Processing Record 29 of Set 15 | lamu
# Processing Record 30 of Set 15 | vestmanna
# Processing Record 31 of Set 15 | port macquarie
# Processing Record 32 of Set 15 | trujillo
# Processing Record 33 of Set 15 | maralal
# Processing Record 34 of Set 15 | uyuni
# Processing Record 35 of Set 15 | kieta
# Processing Record 36 of Set 15 | canete
# Processing Record 37 of Set 15 | evensk
# Processing Record 38 of Set 15 | blackfoot
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Check the number of cities that we have data for
len(city_data)
# Out:
# 681

# %% [markdown]
# # Create and export dataframe

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# Reorder the columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]

# Format the latitude and longitude columns
city_data_df["Lat"] = city_data_df["Lat"].map("{:.2f}".format)
city_data_df["Lng"] = city_data_df["Lng"].map("{:.2f}".format)

city_data_df.head(10)
# Out:
#            City Country     Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0          Hilo      US   19.73  -155.09     82.27        79         100
# 1       Ushuaia      AR  -54.80   -68.30     33.46        80           0
# 2  Saint George      US   37.10  -113.58     84.63        10           0
# 3          Chuy      UY  -33.70   -53.46     51.66        82          18
# 4  Quatre Cocos      MU  -20.21    57.76     73.51        77          16
# 5   Tuktoyaktuk      CA   69.45  -133.04     19.40        86         100
# 6      Nanchong      CN   30.80   106.08     75.34        67           0
# 7  Punta Arenas      CL  -53.15   -70.92     30.31        93          40
# 8    Butaritari      KI    3.07   172.79     82.35        78          67
# 9         Gejiu      CN   23.31   103.16     54.43        97         100
#
#    Wind Speed Current Description
# 0       11.50     overcast clouds
# 1        4.61           clear sky
# 2        9.22           clear sky
# 3        5.39          few clouds
# 4       11.45          few clouds
# 5       14.97     overcast clouds
# 6        1.81           clear sky
# 7        5.75    scattered clouds
# 8       13.73       broken clouds
# 9        2.91     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
